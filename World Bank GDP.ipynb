# %%
import csv
import sqlite3 as lite

con = lite.connect('social_stats.db')
cur = con.cursor()

# %%
import pandas as pd

# %%
df = pd.read_csv('API_NY.GDP.MKTP.CD_DS2_en_csv_v2.csv', header=4, usecols=['Country Name','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010'], encoding='latin1')

# %%
df.columns
# Out:
# Index([u'Country Name',         u'1999',         u'2000',         u'2001',
#                u'2002',         u'2003',         u'2004',         u'2005',
#                u'2006',         u'2007',         u'2008',         u'2009',
#                u'2010'],
#       dtype='object')

# %%
df = df.rename(columns={'Country Name': 'country_name', '1999': '_1999','2000': '_2000','2001': '_2001','2002': '_2002','2003': '_2003','2004': '_2004','2005': '_2005','2006': '_2006','2007': '_2007','2008': '_2008','2009': '_2009','2010': '_2010'})

# %%
df
# Out:
#                          country_name         _1999         _2000  \
# 0                               Aruba  1.722799e+09  1.873453e+09
# 1                             Andorra  1.239840e+09  1.401694e+09
# 2                         Afghanistan           NaN           NaN
# 3                              Angola  6.152937e+09  9.129635e+09
# 4                             Albania  3.414761e+09  3.632044e+09
# 5                          Arab World  6.400000e+11  7.310000e+11
# 6                United Arab Emirates  8.444547e+10  1.040000e+11
# 7                           Argentina  2.840000e+11  2.840000e+11
# 8                             Armenia  1.845482e+09  1.911564e+09
# 9                      American Samoa           NaN           NaN
# 10                Antigua and Barbuda  6.518519e+08  7.838379e+08
# 11                          Australia  3.890000e+11  4.150000e+11
# 12                            Austria  2.170000e+11  1.960000e+11
# ...

# %%
df.to_sql('gdp', con, if_exists='replace')

# %%
with con:
    cur.execute('SELECT * FROM gdp')
    data = cur.fetchall()

# %%
#print data

# %%
df_sql = pd.read_sql('SELECT * FROM gdp', con)

# %%
df_sql
# Out:
#      index                      country_name         _1999         _2000  \
# 0        0                             Aruba  1.722799e+09  1.873453e+09
# 1        1                           Andorra  1.239840e+09  1.401694e+09
# 2        2                       Afghanistan           NaN           NaN
# 3        3                            Angola  6.152937e+09  9.129635e+09
# 4        4                           Albania  3.414761e+09  3.632044e+09
# 5        5                        Arab World  6.400000e+11  7.310000e+11
# 6        6              United Arab Emirates  8.444547e+10  1.040000e+11
# 7        7                         Argentina  2.840000e+11  2.840000e+11
# 8        8                           Armenia  1.845482e+09  1.911564e+09
# 9        9                    American Samoa           NaN           NaN
# 10      10               Antigua and Barbuda  6.518519e+08  7.838379e+08
# 11      11                         Australia  3.890000e+11  4.150000e+11
# ...
